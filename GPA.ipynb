# %%
## Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly

# %% [markdown]
# # 1. Business Understanding
# Goal: ?

# %% [markdown]
# # 2. Data Understanding

# %% [markdown]
# ## 2.1 Load dataset

# %%
## Read *.csv file into pandas DataFrame
FILE_PATH = 'data sets\gpa.xlsx'
df = pd.read_excel(FILE_PATH)
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\g'
# <>:2: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\jared\AppData\Local\Temp\ipykernel_17028\2593805766.py:2: SyntaxWarning: invalid escape sequence '\g'
#   FILE_PATH = 'data sets\gpa.xlsx'
#                   Department  Gender   HSC   SSC  Income Hometown  Computer  \
# 0    Business Administration    Male  4.17  4.84   15000  Village         3
# 1    Business Administration  Female  4.92  5.00   39000     City         3
# 2    Business Administration    Male  5.00  4.83   29000  Village         3
# 3    Business Administration    Male  4.00  4.50  100000     City         5
# 4    Business Administration  Female  2.19  3.17   24000  Village         3
# ..                       ...     ...   ...   ...     ...      ...       ...
# 488            Public Health    Male  3.50  4.00   30000  Village         2
# 489            Public Health    Male  4.50  4.00   43000     City         4
# 490                Sociology  Female  4.56  3.67   21000     City         3
# 491                Sociology    Male  4.23  4.50   13000  Village         3
# 492                Sociology  Female  3.83  5.00   23000  Village         3
#
#      Preparation  Gaming  Attendance  Job  English Extra Semester  Overall  \
# 0            4.0       0         100   No        3   Yes      6th    3.907
# 1            1.0     240          80   No        3   Yes      7th    2.415
# 2            0.0     270          90   No        4   Yes      3rd    2.179
# 3            4.5     180         100   No        5   Yes      4th    2.908
# 4            0.0     180         100   No        3   Yes      4th    2.469
# ..           ...     ...         ...  ...      ...   ...      ...      ...
# 488          6.0     120          50  Yes        2   Yes      7th    3.622
# 489          3.0     120          70   No        3   Yes      9th    3.656
# 490          0.0     180          50   No        2    No      2nd    3.451
# 491          3.0     150          80   No        3   Yes     10th    3.154
# 492          6.0     120         100   No        4   Yes     12th    3.014
#
#       Last
# 0    3.220
# 1    3.467
# 2    4.000
# 3    3.800
# 4    3.940
# ..     ...
# 488  3.250
# 489  3.500
# 490  3.560
# 491  3.610
# 492  4.000
#
# [493 rows x 16 columns]

# %%
df.plot(x='Preparation', y='Last', kind='scatter')
# Out:
# <Axes: xlabel='Preparation', ylabel='Last'>

# %% [markdown]
# ## 2.2 Summary Statistics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Department   493 non-null    object
#  1   Gender       493 non-null    object
#  2   HSC          493 non-null    float64
#  3   SSC          493 non-null    float64
#  4   Income       493 non-null    int64
#  5   Hometown     493 non-null    object
#  6   Computer     493 non-null    int64
#  7   Preparation  493 non-null    float64
#  8   Gaming       493 non-null    int64
#  9   Attendance   493 non-null    int64
#  10  Job          493 non-null    object
#  11  English      493 non-null    int64
#  12  Extra        493 non-null    object
#  13  Semester     493 non-null    object
#  14  Overall      493 non-null    float64
#  15  Last         493 non-null    float64
# dtypes: float64(5), int64(5), object(6)
# memory usage: 61.8+ KB

# %%
df.describe(include='all')
# Out:
#                               Department Gender         HSC         SSC  \
# count                                493    493  493.000000  493.000000
# unique                                10      2         NaN         NaN
# top     Computer Science and Engineering   Male         NaN         NaN
# freq                                 443    328         NaN         NaN
# mean                                 NaN    NaN    4.156775    4.767647
# std                                  NaN    NaN    0.546504    0.349538
# min                                  NaN    NaN    2.170000    3.000000
# 25%                                  NaN    NaN    3.830000    4.680000
# 50%                                  NaN    NaN    4.170000    4.940000
# 75%                                  NaN    NaN    4.500000    5.000000
# max                                  NaN    NaN    5.000000    5.000000
#
#                Income Hometown    Computer  Preparation      Gaming  \
# count      493.000000      493  493.000000   493.000000  493.000000
# unique            NaN        2         NaN          NaN         NaN
# top               NaN  Village         NaN          NaN         NaN
# freq              NaN      280         NaN          NaN         NaN
# mean     39434.077079      NaN    3.338742     1.792089  192.474645
# std      25896.569895      NaN    1.252988     1.387692   61.113997
# min      10000.000000      NaN    1.000000     0.000000    0.000000
# 25%      20000.000000      NaN    3.000000     0.500000  150.000000
# 50%      30000.000000      NaN    3.000000     2.000000  210.000000
# 75%      50000.000000      NaN    4.000000     3.000000  240.000000
# max     100000.000000      NaN    5.000000     6.000000  270.000000
#
#         Attendance  Job     English Extra Semester     Overall        Last
# count   493.000000  493  493.000000   493      493  493.000000  493.000000
# unique         NaN    2         NaN     2       11         NaN         NaN
# top            NaN   No         NaN    No      2nd         NaN         NaN
# freq           NaN  459         NaN   288      183         NaN         NaN
# mean     71.196755  NaN    3.569980   NaN      NaN    2.996428    3.163888
# std      18.902505  NaN    0.870515   NaN      NaN    0.492391    0.641475
# min      10.000000  NaN    1.000000   NaN      NaN    1.683000    1.000000
# 25%      60.000000  NaN    3.000000   NaN      NaN    2.635000    2.810000
# 50%      70.000000  NaN    4.000000   NaN      NaN    2.964000    3.250000
# 75%      90.000000  NaN    4.000000   NaN      NaN    3.356000    3.670000
# max     100.000000  NaN    5.000000   NaN      NaN    4.000000    4.000000

# %%
## Check for missing data
df.isna().sum()
# Out:
# Department     0
# Gender         0
# HSC            0
# SSC            0
# Income         0
# Hometown       0
# Computer       0
# Preparation    0
# Gaming         0
# Attendance     0
# Job            0
# English        0
# Extra          0
# Semester       0
# Overall        0
# Last           0
# dtype: int64

# %%
## Describe data distribution

# %% [markdown]
# ## 2.3 Data Visualization

# %% [markdown]
# ### 2.3.1 Understanding distribution of data

# %% [markdown]
# ### 2.3.1.1 Understanding distribution of target

# %%
## Understanding distribution of target
df.boxplot()
plt.show()

# %% [markdown]
# ### 2.3.1.2 Understanding distribution of features

# %%
## Understanding distribution of features
col_y = 'Overall'
df[col_y].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### 2.3.2 Understanding relationship between variables

# %%
## Understanding relationship between variables
sns.pairplot(df, hue=col_y)
plt.show()

# %% [markdown]
# # 3. Data Preparation

# %% [markdown]
# ## 3.1 Data Cleaning

# %%
## Clean data

# %% [markdown]
# ## 3.2 Train-Test Split

# %%
# Split data into features (X) and target (y)
y = df[col_y] ## Select target column
 
col_irrelevant = [col_y, 'Department', 'Semester']
 
X = df.drop(col_irrelevant, axis=1) ## Select feature columns
 
## One-Hot Encoding
X = pd.get_dummies(X, drop_first=True) ## Remove redundant information


from sklearn.model_selection import train_test_split
test_size = 0.3
random_state = 2025
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

# %% [markdown]
# # 4. Modelling

# %% [markdown]
# ### 4.2 Train Model

# %%
## Initialise and train model
from sklearn.linear_model import LinearRegression
linr = LinearRegression(fit_intercept=True)
linr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 5. Model Evaluation

# %%
## Evaluate model
y_pred_linr =linr.predict(X_test) ## Predict using model 1
 
## Calculate error
E = y_pred_linr - y_test
E
# Out:
# 48    -0.050129
# 411    0.155187
# 318   -0.069586
# 416   -0.102129
# 362   -0.070553
#          ...
# 481   -0.120376
# 155   -0.140692
# 24     0.033869
# 370    0.025271
# 440    0.005267
# Name: Overall, Length: 148, dtype: float64

# %%
AE = np.abs(E)
MAE = np.mean(AE)
SE = E**2
MSE = np.mean(SE)
MSE
## Calculate root mean squared error
RMSE = np.sqrt(MSE)
RMSE
# Out:
# np.float64(0.0783813838294382)

# %%
## Display linear regression equation
" + ".join([f"{coef:.2f} {name}"
   for name, coef
   in zip(linr.feature_names_in_,
   linr.coef_)])
 
## How do we interpret the equation below? Any issues with the interpretation?
# Out:
# '-0.02 HSC + -0.01 SSC + -0.00 Income + 0.12 Computer + 0.00 Preparation + -0.01 Gaming + -0.01 Attendance + -0.01 English + -0.01 Last + 0.00 Gender_Male + 0.00 Hometown_Village + -0.00 Job_Yes + -0.02 Extra_Yes'

# %%
## Save model
import joblib
joblib.dump(linr,'gpa_linr_model.pkl') ## Save Gradient Boosted Tree model
# Out:
# ['gpa_linr_model.pkl']

# %%
## New data

## Predict
